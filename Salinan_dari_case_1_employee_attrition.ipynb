# %% [markdown]
# <a href="https://colab.research.google.com/github/saifulrijal-ds/python-datascience/blob/master/Salinan_dari_case_1_employee_attrition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
exist_employ = pd.read_excel("/content/TakenMind-Python-Analytics-Problem-case-study-1-1.xlsx", sheet_name="Existing employees")
exist_employ
# Out:
#        Emp ID  satisfaction_level  ...        dept  salary
# 0        2001                0.58  ...       sales     low
# 1        2002                0.82  ...       sales     low
# 2        2003                0.45  ...       sales     low
# 3        2004                0.78  ...       sales     low
# 4        2005                0.49  ...       sales     low
# ...       ...                 ...  ...         ...     ...
# 11423   14207                0.90  ...  management    high
# 11424   14208                0.74  ...  management    high
# 11425   14209                0.85  ...  management    high
# 11426   14210                0.33  ...   marketing    high
# 11427   14211                0.50  ...          IT     low
#
# [11428 rows x 10 columns]

# %%
exist_employ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11428 entries, 0 to 11427
# Data columns (total 10 columns):
# Emp ID                   11428 non-null int64
# satisfaction_level       11428 non-null float64
# last_evaluation          11428 non-null float64
# number_project           11428 non-null int64
# average_montly_hours     11428 non-null int64
# time_spend_company       11428 non-null int64
# Work_accident            11428 non-null int64
# promotion_last_5years    11428 non-null int64
# dept                     11428 non-null object
# salary                   11428 non-null object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 892.9+ KB

# %%
left_employ = pd.read_excel("TakenMind-Python-Analytics-Problem-case-study-1-1.xlsx", sheet_name="Employees who have left")
left_employ
# Out:
#       Emp ID  satisfaction_level  ...     dept  salary
# 0          1                0.38  ...    sales     low
# 1          2                0.80  ...    sales  medium
# 2          3                0.11  ...    sales  medium
# 3          4                0.72  ...    sales     low
# 4          5                0.37  ...    sales     low
# ...      ...                 ...  ...      ...     ...
# 3566   14995                0.40  ...  support     low
# 3567   14996                0.37  ...  support     low
# 3568   14997                0.37  ...  support     low
# 3569   14998                0.11  ...  support     low
# 3570   14999                0.37  ...  support     low
#
# [3571 rows x 10 columns]

# %%
left_employ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3571 entries, 0 to 3570
# Data columns (total 10 columns):
# Emp ID                   3571 non-null int64
# satisfaction_level       3571 non-null float64
# last_evaluation          3571 non-null float64
# number_project           3571 non-null int64
# average_montly_hours     3571 non-null int64
# time_spend_company       3571 non-null int64
# Work_accident            3571 non-null int64
# promotion_last_5years    3571 non-null int64
# dept                     3571 non-null object
# salary                   3571 non-null object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 279.1+ KB

# %%
exist_employ["left"] = 0
exist_employ
# Out:
#        Emp ID  satisfaction_level  last_evaluation  ...        dept  salary  left
# 0        2001                0.58             0.74  ...       sales     low     0
# 1        2002                0.82             0.67  ...       sales     low     0
# 2        2003                0.45             0.69  ...       sales     low     0
# 3        2004                0.78             0.82  ...       sales     low     0
# 4        2005                0.49             0.60  ...       sales     low     0
# ...       ...                 ...              ...  ...         ...     ...   ...
# 11423   14207                0.90             0.55  ...  management    high     0
# 11424   14208                0.74             0.95  ...  management    high     0
# 11425   14209                0.85             0.54  ...  management    high     0
# 11426   14210                0.33             0.65  ...   marketing    high     0
# ...

# %%
left_employ["left"] = 1
left_employ
# Out:
#       Emp ID  satisfaction_level  last_evaluation  ...     dept  salary  left
# 0          1                0.38             0.53  ...    sales     low     1
# 1          2                0.80             0.86  ...    sales  medium     1
# 2          3                0.11             0.88  ...    sales  medium     1
# 3          4                0.72             0.87  ...    sales     low     1
# 4          5                0.37             0.52  ...    sales     low     1
# ...      ...                 ...              ...  ...      ...     ...   ...
# 3566   14995                0.40             0.57  ...  support     low     1
# 3567   14996                0.37             0.48  ...  support     low     1
# 3568   14997                0.37             0.53  ...  support     low     1
# 3569   14998                0.11             0.96  ...  support     low     1
# 3570   14999                0.37             0.52  ...  support     low     1
#
# [3571 rows x 11 columns]

# %%
# employee = exist_employ.append(left_employ, ignore_index=True, verify_integrity=True)
# employee

# %%
# employee.sort_values(by=["Emp ID"])

# %%
# employee

# %%
employee1 = pd.concat([exist_employ, left_employ], ignore_index=True, verify_integrity=True)
employee1
# Out:
#        Emp ID  satisfaction_level  last_evaluation  ...     dept  salary  left
# 0        2001                0.58             0.74  ...    sales     low     0
# 1        2002                0.82             0.67  ...    sales     low     0
# 2        2003                0.45             0.69  ...    sales     low     0
# 3        2004                0.78             0.82  ...    sales     low     0
# 4        2005                0.49             0.60  ...    sales     low     0
# ...       ...                 ...              ...  ...      ...     ...   ...
# 14994   14995                0.40             0.57  ...  support     low     1
# 14995   14996                0.37             0.48  ...  support     low     1
# 14996   14997                0.37             0.53  ...  support     low     1
# 14997   14998                0.11             0.96  ...  support     low     1
# 14998   14999                0.37             0.52  ...  support     low     1
#
# ...

# %%
employee1 = employee1.sort_values(by=["Emp ID"])
employee1.to_excel("employee.xlsx", sheet_name="all employee", index=False)

# %%
employee = pd.read_excel("/content/employee.xlsx")
employee
# Out:
#        Emp ID  satisfaction_level  last_evaluation  ...     dept  salary  left
# 0           1                0.38             0.53  ...    sales     low     1
# 1           2                0.80             0.86  ...    sales  medium     1
# 2           3                0.11             0.88  ...    sales  medium     1
# 3           4                0.72             0.87  ...    sales     low     1
# 4           5                0.37             0.52  ...    sales     low     1
# ...       ...                 ...              ...  ...      ...     ...   ...
# 14994   14995                0.40             0.57  ...  support     low     1
# 14995   14996                0.37             0.48  ...  support     low     1
# 14996   14997                0.37             0.53  ...  support     low     1
# 14997   14998                0.11             0.96  ...  support     low     1
# 14998   14999                0.37             0.52  ...  support     low     1
#
# ...

# %%
sns.boxplot(x="left", y="satisfaction_level", data=employee)

# %%
sns.boxplot(x="left", y="last_evaluation", data=employee)

# %%
sns.boxplot(x="left", y="average_montly_hours", data=employee)

# %%
sns.countplot(y="dept", hue="left", data=employee)

# %%
sns.countplot(y="salary", hue="left", data=employee)
